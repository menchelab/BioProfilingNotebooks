# %%
using CSV, StatsBase, Statistics, DataFrames, RCall, FreqTables
using MultipleTesting, Random, MultivariateStats, Distributed
using ParallelDataTransfer
using BioProfiling, UMAP

# %%
using Dates: now
now()
# Out:
# 2021-05-07T18:37:35.551

# %%
# Set the number of processes to use for parallel computing
addprocs(16)
pool = CachingPool(workers())
# Out:
# CachingPool(Channel{Int64}(sz_max:9223372036854775807,sz_curr:16), Set([2, 16, 11, 7, 9, 10, 17, 8, 6, 4, 3, 5, 13, 14, 15, 12]), IdDict{Tuple{Int64,Function},RemoteChannel}())

# %% [markdown]
# ## R Calls

# %%
@rlibrary ggplot2
@rlibrary extrafont
@rlibrary viridis
@rlibrary heatmaply
@rlibrary ggrepel

# %%
R"""
# Used later for MCD computation

library(robustbase)

# Customize ggplot appearance

library(ggplot2)
library(extrafont)


# Load extra fonts
# ttf_import("/tmp/.fonts")
# loadfonts()

# Change theme
customTheme <- theme_light() + 
               theme(panel.grid.minor=element_blank(), text=element_text(size=17, family="Arial", colour = "#333333"),
                     line=element_line(colour = "#333333"), 
                     legend.background = element_rect(fill=alpha('#CCCCCC', 0.1)), legend.key = element_blank())

# Change default colors
scale_colour_continuous <- function (..., begin = 0.1, end = 0.9, direction = -1, option = "plasma", 
                                     type = getOption("ggplot2.continuous.colour", default = "viridis")) {
    switch(type, gradient = scale_colour_gradient(...), 
        viridis = scale_colour_viridis_c(option = option, begin = begin, end = end, direction = direction, ...), 
        stop("Unknown scale type", call. = FALSE))
}
scale_color_continuous <- scale_colour_continuous

scale_fill_continuous <- function (..., begin = 0.1, end = 0.9, direction = -1, option = "plasma", 
                                     type = getOption("ggplot2.continuous.colour", default = "viridis")) {
    switch(type, gradient = scale_fill_gradient(...), 
        viridis = scale_fill_viridis_c(option = option, begin = begin, end = end, direction = direction, ...), 
        stop("Unknown scale type", call. = FALSE))

}

cemm_pal = colorRampPalette(c("#5A463C", "#008CAD", "#40B9D4", "#D4ECF2", "#D2323C", "#F8B100", "#DFDC00"))
scale_fill_discrete <- function (..., type = "CeMM", h = c(0, 360) + 15, c = 100, l = 65, h.start = 0, 
    direction = 1, na.value = "grey50", aesthetics = "fill") 
{
    if (type == "CeMM"){
        discrete_scale(aesthetics, "CeMM", cemm_pal, na.value = na.value, ...)
    } else {
        discrete_scale(aesthetics, "hue", hue_pal(h, c, l, h.start, 
            direction), na.value = na.value, ...)
    }
}

scale_color_discrete <- function (..., type = "CeMM", h = c(0, 360) + 15, c = 100, l = 65, h.start = 0, 
    direction = 1, na.value = "grey50", aesthetics = "colour") {
    if (type == "CeMM"){
        discrete_scale(aesthetics, "CeMM", cemm_pal, na.value = na.value, ...)
    } else {
        discrete_scale(aesthetics, "hue", scales::hue_pal(h, c, l, h.start, 
            direction), na.value = na.value, ...)
    }
}
scale_colour_discrete <- scale_color_discrete

noGridTheme <- function(...){
    theme(panel.grid.major=element_blank(), axis.text.x=element_text(size=12), axis.text.y=element_text(size=12),
                      axis.line=element_line(color="#333333", size = 0.2), panel.border = element_blank(), ...)
}

darkTheme <- function(...){
    theme(panel.background = element_rect(fill = '#333333'), plot.background = element_rect(fill = '#333333'), 
          axis.line=element_line(color="#CCCCCC", size = 0.2), 
          text=element_text(size=17, family="Arial", colour = "#CCCCCC"),
          line=element_line(colour = "#CCCCCC"))
}

theme_set(customTheme)

options(repr.plot.width=10, repr.plot.height=10)
"""
# Out:
# ┌ Warning: RCall.jl: Registering fonts with R
# └ @ RCall /opt/julia/packages/RCall/3mHXJ/src/io.jl:160
# RObject{VecSxp}
# $repr.plot.width
# NULL
#
# $repr.plot.height
# NULL

# %% [markdown]
# ## Load measurements

# %% [markdown]
# ### Load annotations

# %%
annotations = CSV.read("data/transferList.txt", DataFrame, header = 1, delim = "\t")
# Convert plate number to strings to make clear it is an ID and should not be used for computations
annotations[!,:DestinationPlate] = string.(annotations[:,:DestinationPlate])
# Wells in the transfer list without any compound name are filled with DMSO only
annotations[!,:CompoundName][ismissing.(annotations[:,:CompoundName])] .= "DMSO"
# A non-ASCII characters needs to be converted
annotations.CompoundName = replace.(annotations.CompoundName, "\xb1" => s"±");

# %%
annotations
# Out:
# 5488×17 DataFrame
#   Row │ DestWell  SourcePlate_A  SrcWell_A  DestinationPlate  Type_A  VolumeTr ⋯
#       │ String    String         String     String            String  Int64    ⋯
# ──────┼─────────────────────────────────────────────────────────────────────────
#     1 │ A01       CLOMP_D4       M04        1914001           Cpd              ⋯
#     2 │ A02       CLOUD10mM10    I19        1914001           Cpd
#     3 │ A03       CLOUD10mM10    A10        1914001           Cpd
#     4 │ A04       CLOMP002a      L04        1914001           Cpd
#     5 │ A05       CLOUD10mM10    I05        1914001           Cpd              ⋯
#     6 │ A06       CLOMP002a      B11        1914001           Cpd
#     7 │ A07       CLOMP001a      F15        1914001           Cpd
#     8 │ A08       CLOMP003a      I20        1914001           Cpd
#     9 │ A09       CLOUD10mM10    M19        1914001           Cpd              ⋯
#    10 │ A10       CLOMP003a      M17        1914001           Cpd
#    11 │ A11       CLOMP004a      O20        1914001           Cpd
#   ⋮   │    ⋮            ⋮            ⋮             ⋮            ⋮              ⋱
#  5479 │ P15       CLOMP003a      J14        1914016           Cpd
#  5480 │ P16       CLOMP002a      E13        1914016           Cpd              ⋯
#  5481 │ P17       CLOMP_D2       O17        1914016           Cpd
#  5482 │ P18       CLOMP004a      K13        1914016           Cpd
#  5483 │ P19       CLOMP004a      D16        1914016           Cpd
#  5484 │ P20       CLOUD10mM10    E23        1914016           Cpd              ⋯
#  5485 │ P21       CLOMP004a      C06        1914016           Cpd
#  5486 │ P22       CLOUD10mM10    G21        1914016           Cpd
#  5487 │ P23       CLOMP_D2       L12        1914016           Cpd
#  5488 │ P24       CLOMP004a      I05        1914016           Cpd              ⋯
#                                                 12 columns and 5467 rows omitted

# %% [markdown]
# ### Load image data

# %%
image = CSV.read("data/compiled_PilotDrugScreen_Image_1500.csv", DataFrame)
println(string.(names(image))[1:8])
# Number of images and features available
println(nrow(image))
println(ncol(image))
# Out:
# ["Column1", "AreaOccupied_AreaOccupied_CytoCM", "AreaOccupied_AreaOccupied_Cytoplasm", "AreaOccupied_AreaOccupied_Nucleus", "AreaOccupied_Perimeter_CytoCM", "AreaOccupied_Perimeter_Cytoplasm", "AreaOccupied_Perimeter_Nucleus", "AreaOccupied_TotalArea_CytoCM"]
# 7680
# 1916

# %% [markdown]
# ## Coarse-grain aggregation

# %%
aggregatedData = CSV.read("data/aggregatedData_1500cells_noSparse.csv", DataFrame);

# %% [markdown]
# ### Transform aggregated data - Normalization
# We want to focus on variables that are changing more overall than inside of reference condition (untreated WT).

# %%
expAgg = Experiment(aggregatedData, description = "Median values for aggregated FOV measurements")
# Out:
# "Experiment with 7020/7020 entries and 390/390 features selected."

# %%
filters = Array{BioProfiling.AbstractSelector,1}()
# Remove metadata
strToRemove = ["Metadata_Well", "CompoundName", "Metadata_Field", "Metadata_Row", "Metadata_Column"]
push!(filters, NameSelector(x -> !any(occursin.(strToRemove, String(x)))))
# Remove constant columns
push!(filters, Selector(x -> mad(x, normalize = true) != 0, description = "Remove constant features"));
push!(filters, Selector(x -> mad(x, normalize = true) != 0, 
                        subset = x -> x.CompoundName .== "DMSO", 
                        description = "Remove features constant for reference"))
select_features!(expAgg, filters)

# %%
expTransformed = deepcopy(expAgg)
logtransform!(expTransformed)
expTransformed.description = "Transformed values for aggregated FOV measurements"
# Out:
# "Transformed values for aggregated FOV measurements"

# %% [markdown]
# Here we apply a correction based on the specific details of the experimental design:
# All rows and columns include DMSO (negative) controls and we normalize all values based on these matchings controls (same row and column).
#
# This examplifies how to directly modify the data of an `Experiment` object.
#
# NB: One might want to check that more iterations are not needed (cf. Median-polish method).

# %%
# Normalize on matching DMSO wells median values

# Entries in both data frames are matching
@assert nrow(aggregatedData) == nrow(getdata(expTransformed))

# Copy data before correction
ndf = getdata(expTransformed)

for (i, (fx, fy)) in enumerate(eachrow(aggregatedData[:,[:Metadata_Row, :Metadata_Column]])) 
    c1 = aggregatedData.CompoundName .== "DMSO"
    c2 = aggregatedData.Metadata_Row .== fx
    c3 = aggregatedData.Metadata_Column .== fy
    @assert sum((c1 .& (c2 .| c3))) > 0
    expTransformed.data[i:i, expTransformed.selected_features] .-= 
        mapcols(median, ndf[(c1 .& (c2 .| c3)),:]) 
    expTransformed.data[i:i, expTransformed.selected_features] ./= 
        mapcols(mad, ndf[(c1 .& (c2 .| c3)),:]) 
end

select_features!(expTransformed,
                 Selector(x -> !any(isinf.(x)), 
                        description = "Remove features with infinite values " *
                            "(i.e. with no variation for a subset of the DMSO images)"));

decorrelate_by_mad!(expTransformed);

# %% [markdown]
# ## Visualization

# %%
using Distances

# %%
Random.seed!(3895)
umTPM = umap(expTransformed, metric = CosineDist(), min_dist = 2)
umTPM = convert(DataFrame, umTPM')
rename!(umTPM, [:UMAP1, :UMAP2]);
umTPM.Compound = aggregatedData.CompoundName

subsetCompounds = ["Vinblastine", "Pentamidine", "Furamidine", "DMSO"]
subsetEntries = Bool.(map(sum, eachcol(map(x -> occursin.(x, umTPM.Compound), subsetCompounds)))[1])
ggplot(umTPM[subsetEntries,:], aes(:UMAP1, :UMAP2)) + 
    geom_point(aes(color = :Compound), alpha = 0.8) +
    coord_fixed() + 
    theme(var"legend.position"="bottom", var"legend.spacing.x" = unit(0.35, "cm"), 
    var"legend.spacing.y" = unit(0, "cm")) + 
    guides(color=guide_legend(nrow=3,byrow=true))
# Out:
# RObject{VecSxp}

# %% [markdown]
# ## Distance to DMSO

# %% [markdown]
# ### UMAP-based distance

# %%
Random.seed!(3895)
umTPM = umap(expTransformed, 4, metric = CosineDist(), min_dist = 2)
umTPM = convert(DataFrame, umTPM')
rename!(umTPM, [:UMAP1, :UMAP2, :UMAP3, :UMAP4])
umTPM.Compound = aggregatedData.CompoundName;

# %%
expUMAP = Experiment(umTPM, description = "UMAP projection of profiling data")
# Out:
# "Experiment with 7020/7020 entries and 5/5 features selected."

# %%
filters = Array{BioProfiling.AbstractReduce,1}()
# Remove (categorical) compound column from analysis
push!(filters, NameSelector(x -> x != "Compound"))
# Remove entries for compounds not present often enough
cmpd_to_keep = levels(umTPM.Compound)[freqtable(umTPM.Compound) .>= 8]
compare_in(x,y) = x in y
Broadcast.broadcasted(::typeof(compare_in), x, y) = broadcast(in, x, Ref(y))
push!(filters, Filter(cmpd_to_keep, :Compound, compare = compare_in))
# Apply filters
filter!(expUMAP, filters)
expUMAP
# Out:
# "Experiment with 6949/7020 entries and 4/5 features selected."

# %% [markdown]
# NB: because the `compare` function of Filter `f` is applied as f.compare.(entries, f.value)
# the value provided needs to be of the length of the entries or of length 1.
# Otherwise, when broadcasting (calling `f.compare` on all elements with `f.compare.`), we need to specify that the `f.value` should be used "as is". This is done by overloading the broadcasting of the function. See:
# https://discourse.julialang.org/t/how-to-broadcast-over-only-certain-function-arguments/19274/5
# Another "trick" is to use a function that takes a length 1 value that is in practice not used:
# ```julia
# push!(filters, Filter("NotUsed", :Compound, compare = (x,y) -> (x in cmpd_to_keep)))
# ```

# %%
# The following RMD values are displayed in the following order:
selectedCompounds = expUMAP.data[expUMAP.selected_entries, :Compound]
levels(selectedCompounds)
# Out:
# 287-element Array{String,1}:
#  "(+)-Butaclamol hydrochloride"
#  "(+)-Cyclazocine"
#  "(+/-)-Sulfinpyrazone"
#  "(-)-JQ1"
#  "(-)-Perillic acid"
#  "(-)-Quinpirole hydrochloride"
#  "(-)-trans-(1S,2S)-U-50488 hydrochloride"
#  "(S)-(+)-Camptothecin"
#  "(S)-Propranolol hydrochloride"
#  "(±)-Isoproterenol hydrochloride"
#  "(±)-Methoxyverapamil hydrochloride"
#  "(±)-Metoprolol (+)-tartrate"
#  "(±)-Octoclothepin maleate"
#  ⋮
#  "U-62066"
#  "U0126"
#  "UNC0379 trifluoroacetate salt"
#  "Vinblastine"
#  "Vincristine sulfate"
#  "WIN 62,577"
#  "WZ4003"
#  "Wiskostatin"
#  "XL388"
#  "Y-27632 dihydrochloride"
#  "Yoda1"
#  "alpha-Lobeline hydrochloride"

# %% [markdown]
# ### Compute Robust Morphological Perturbation Value (RMPV)

# %% [markdown]
# Note: with previous versions of Julia, pmap was slower than using SharedArrays and a `@sync @distributed for` loops. This is not the case for Julia 1.5, so we use pmap for the sake of readability.

# %%
now()
# Out:
# 2021-05-07T21:04:27.272

# %% [markdown]
# Takes ~1h40mn with 16 cores

# %%
@everywhere using BioProfiling
plateRMPV = robust_morphological_perturbation_value(expUMAP, :Compound, "DMSO"; 
    nb_rep = 5000, dist = :RobHellinger, process_pool = pool)
# Out:
# ┌ Warning: RCall.jl: Loading required package: robustbase
# └ @ RCall /opt/julia/packages/RCall/3mHXJ/src/io.jl:160
# ┌ Warning: RCall.jl: Loading required package: robustbase
# └ @ RCall /opt/julia/packages/RCall/3mHXJ/src/io.jl:160
# ┌ Warning: RCall.jl: Loading required package: robustbase
# └ @ RCall /opt/julia/packages/RCall/3mHXJ/src/io.jl:160
# ┌ Warning: RCall.jl: Loading required package: robustbase
# └ @ RCall /opt/julia/packages/RCall/3mHXJ/src/io.jl:160
# ┌ Warning: RCall.jl: Loading required package: robustbase
# └ @ RCall /opt/julia/packages/RCall/3mHXJ/src/io.jl:160
# ┌ Warning: RCall.jl: Loading required package: robustbase
# └ @ RCall /opt/julia/packages/RCall/3mHXJ/src/io.jl:160
# ┌ Warning: RCall.jl: Loading required package: robustbase
# └ @ RCall /opt/julia/packages/RCall/3mHXJ/src/io.jl:160
# ┌ Warning: RCall.jl: Loading required package: robustbase
# └ @ RCall /opt/julia/packages/RCall/3mHXJ/src/io.jl:160
# ┌ Warning: RCall.jl: Loading required package: robustbase
# └ @ RCall /opt/julia/packages/RCall/3mHXJ/src/io.jl:160
# ┌ Warning: RCall.jl: Loading required package: robustbase
# └ @ RCall /opt/julia/packages/RCall/3mHXJ/src/io.jl:160
# ┌ Warning: RCall.jl: Loading required package: robustbase
# └ @ RCall /opt/julia/packages/RCall/3mHXJ/src/io.jl:160
# ┌ Warning: RCall.jl: Loading required package: robustbase
# └ @ RCall /opt/julia/packages/RCall/3mHXJ/src/io.jl:160
# ┌ Warning: RCall.jl: Loading required package: robustbase
# └ @ RCall /opt/julia/packages/RCall/3mHXJ/src/io.jl:160
# ┌ Warning: RCall.jl: Loading required package: robustbase
# └ @ RCall /opt/julia/packages/RCall/3mHXJ/src/io.jl:160
# ┌ Warning: RCall.jl: Loading required package: robustbase
# └ @ RCall /opt/julia/packages/RCall/3mHXJ/src/io.jl:160
# ┌ Warning: RCall.jl: Loading required package: robustbase
# └ @ RCall /opt/julia/packages/RCall/3mHXJ/src/io.jl:160
# 287×3 DataFrame
#  Row │ RMPV         Distance  Condition
#      │ Float64      Float64   String
# ─────┼──────────────────────────────────────────────────────────
#    1 │ 0.0          0.77051   (+)-Butaclamol hydrochloride
#    2 │ 0.00124783   0.712834  (+)-Cyclazocine
#    3 │ 0.015413     0.627183  (+/-)-Sulfinpyrazone
#    4 │ 0.0          0.77281   (-)-JQ1
#    5 │ 0.00182222   0.704824  (-)-Perillic acid
#    6 │ 0.106131     0.518918  (-)-Quinpirole hydrochloride
#    7 │ 0.027791     0.600247  (-)-trans-(1S,2S)-U-50488 hydroc…
#    8 │ 0.0          0.972026  (S)-(+)-Camptothecin
#    9 │ 0.0          0.773574  (S)-Propranolol hydrochloride
#   10 │ 0.0          0.760293  (±)-Isoproterenol hydrochloride
#   11 │ 0.000652273  0.734957  (±)-Methoxyverapamil hydrochlori…
#   ⋮  │      ⋮          ⋮                      ⋮
#  278 │ 0.0          0.851013  UNC0379 trifluoroacetate salt
#  279 │ 0.18595      0.466833  Vinblastine
#  280 │ 0.0          0.922948  Vincristine sulfate
#  281 │ 0.00208187   0.669203  WIN 62,577
#  282 │ 0.0          0.998964  WZ4003
#  283 │ 0.0          0.929512  Wiskostatin
#  284 │ 0.0          0.998369  XL388
#  285 │ 0.00568317   0.673533  Y-27632 dihydrochloride
#  286 │ 0.0443088    0.578399  Yoda1
#  287 │ 0.0347489    0.591571  alpha-Lobeline hydrochloride
#                                                 266 rows omitted

# %%
now()
# Out:
# 2021-05-07T22:34:34.638

# %%
# Missing values might need to be handled
@assert !any(ismissing.(plateRMPV.RMPV))

# %%
# Export to avoid recomputing if not necessary
CSV.write("data/RMPV_1500.csv", plateRMPV);

# %%
cpd_to_label = ["DMSO", "Vinblastine", "Pentamidine", "Wiskostatin", 
     "Gefitinib", "Imatinib", "Hydroxychloroquine"]
plateRMPV.Label = [x in cpd_to_label ? x : "" for x in plateRMPV.Condition];

# %%
# Display number of positive tests
gp = ggplot(plateRMPV, aes(x = :RMPV, y = :Distance)) + geom_point(aes(color = :Condition)) + 
    geom_vline(xintercept = 0.05, linetype = "dashed") +
    geom_label_repel(aes(label = :Label), size = 5) + 
    guides(color = false) +
    xlab("FDR-corrected p-value") +
    ylab("Robust Hellinger Distance") +
    RObject(nothing)
print(gp);
# Out:
# RObject{VecSxp}
# ┌ Warning: RCall.jl: Warning: ggrepel: 6 unlabeled data points (too many overlaps). Consider increasing max.overlaps
# └ @ RCall /opt/julia/packages/RCall/3mHXJ/src/io.jl:160

# %%
ggsave("fig/UMAP_RMPV_test_hellinger_annotated_1500.pdf", gp);
# Out:
# REvalError: Saving 7 x 7 in image
# Warning in grid.Call(C_stringMetric, as.graphicsAnnot(x$label)) :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_stringMetric, as.graphicsAnnot(x$label)) :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_stringMetric, as.graphicsAnnot(x$label)) :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_stringMetric, as.graphicsAnnot(x$label)) :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_stringMetric, as.graphicsAnnot(x$label)) :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_stringMetric, as.graphicsAnnot(x$label)) :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_stringMetric, as.graphicsAnnot(x$label)) :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_stringMetric, as.graphicsAnnot(x$label)) :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_stringMetric, as.graphicsAnnot(x$label)) :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_stringMetric, as.graphicsAnnot(x$label)) :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_stringMetric, as.graphicsAnnot(x$label)) :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_stringMetric, as.graphicsAnnot(x$label)) :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_stringMetric, as.graphicsAnnot(x$label)) :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_stringMetric, as.graphicsAnnot(x$label)) :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_stringMetric, as.graphicsAnnot(x$label)) :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_stringMetric, as.graphicsAnnot(x$label)) :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_stringMetric, as.graphicsAnnot(x$label)) :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_stringMetric, as.graphicsAnnot(x$label)) :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_stringMetric, as.graphicsAnnot(x$label)) :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_stringMetric, as.graphicsAnnot(x$label)) :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_stringMetric, as.graphicsAnnot(x$label)) :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_stringMetric, as.graphicsAnnot(x$label)) :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_stringMetric, as.graphicsAnnot(x$label)) :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_stringMetric, as.graphicsAnnot(x$label)) :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_stringMetric, as.graphicsAnnot(x$label)) :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_stringMetric, as.graphicsAnnot(x$label)) :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_stringMetric, as.graphicsAnnot(x$label)) :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_stringMetric, as.graphicsAnnot(x$label)) :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning: ggrepel: 6 unlabeled data points (too many overlaps). Consider increasing max.overlaps
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Error in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y,  :
#   invalid font type
# Calls: <Anonymous> ... drawDetails -> drawDetails.text -> grid.Call.graphics
#
# Stacktrace:
#  [1] handle_eval_stderr(; as_warning::Bool) at /opt/julia/packages/RCall/3mHXJ/src/io.jl:162
#  [2] reval_p(::Ptr{LangSxp}, ::Ptr{EnvSxp}) at /opt/julia/packages/RCall/3mHXJ/src/eval.jl:99
#  [3] reval_p at /opt/julia/packages/RCall/3mHXJ/src/eval.jl:95 [inlined]
#  [4] rcall_p(::RObject{ClosSxp}, ::String, ::Vararg{Any,N} where N; kwargs::Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}) at /opt/julia/packages/RCall/3mHXJ/src/language.jl:30
#  [5] rcall_p(::RObject{ClosSxp}, ::String, ::Vararg{Any,N} where N) at /opt/julia/packages/RCall/3mHXJ/src/language.jl:30
#  [6] rcall(::RObject{ClosSxp}, ::String, ::Vararg{Any,N} where N; kwargs::Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}) at /opt/julia/packages/RCall/3mHXJ/src/language.jl:37
#  [7] rcall(::RObject{ClosSxp}, ::String, ::Vararg{Any,N} where N) at /opt/julia/packages/RCall/3mHXJ/src/language.jl:37
#  [8] (::RObject{ClosSxp})(::String, ::Vararg{Any,N} where N; kwargs::Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}) at /opt/julia/packages/RCall/3mHXJ/src/language.jl:39
#  [9] (::RObject{ClosSxp})(::String, ::Vararg{Any,N} where N) at /opt/julia/packages/RCall/3mHXJ/src/language.jl:39
#  [10] top-level scope at In[27]:1
#  [11] include_string(::Function, ::Module, ::String, ::String) at ./loading.jl:1091

# %% [markdown]
# With this method, we find 229 strong hits (FDR .05) or 242 (FDR .1).

# %%
println.(plateRMPV[plateRMPV.RMPV .< 0.1,:Condition]);
# Out:
# (+)-Butaclamol hydrochloride
# (+)-Cyclazocine
# (+/-)-Sulfinpyrazone
# (-)-JQ1
# (-)-Perillic acid
# (-)-trans-(1S,2S)-U-50488 hydrochloride
# (S)-(+)-Camptothecin
# (S)-Propranolol hydrochloride
# (±)-Isoproterenol hydrochloride
# (±)-Methoxyverapamil hydrochloride
# (±)-Octoclothepin maleate
# (±)-SKF-38393 hydrochloride
# (±)-Verapamil hydrochloride
# (±)-alpha-Lipoic Acid
# 1,10-Phenanthroline monohydrate
# 2,2'-Bipyridyl
# 2,3-Dimethoxy-1,4-naphthoquinone
# 2-Phenylaminoadenosine
# 4-(2-Aminoethyl)benzenesulfonyl fluoride hydrochloride
# 5-(N,N-hexamethylene)amiloride
# 5-(N-Ethyl-N-isopropyl)amiloride
# 5-Bromo-2'-deoxyuridine
# 5-Fluorouracil
# 5-azacytidine
# 5alpha-Pregnan-3alpha-ol-20-one
# 6-Nitroso-1,2-benzopyrone
# 7-Cyclopentyl-5-(4-phenoxy)phenyl-7H-pyrrolo[2,3-d]pyrimidin-4-ylamine
# AC-93253 iodide
# AEG 3482
# AMG 9810
# Acepromazine maleate
# Albendazole
# Ammonium pyrrolidinedithiocarbamate
# Amodiaquine
# Ancitabine hydrochloride
# Apomorphine hydrochloride hemihydrate
# Aurora-A Inhibitor I
# BAY 61-3606 hydrochloride hydrate
# BIO
# BMS-193885
# BRD3308
# BTO-1
# BW 723C86
# Benidipine hydrochloride
# Benoxathian hydrochloride
# Benzamil hydrochloride
# Benztropine mesylate
# Brefeldin A from Penicillium brefeldianum
# Brequinar sodium salt hydrate
# Budesonide
# CCCI-01
# CCT137690
# CID 11210285 hydrochloride
# CID2858522
# CP466722
# CYM50358
# Caffeic Acid
# Caffeic acid phenethyl ester
# Cantharidic Acid
# Cantharidin
# Carmofur
# Carvedilol
# Chloroquine
# Chlorprothixene hydrochloride
# Cilengitide trifluoroacetic acid salt
# Cilnidipine
# Clemizole hydrochloride
# Clodronic acid
# Clofarabine
# Clomipramine hydrochloride
# Clotrimazole
# Cyclosporin A
# Cyproterone acetate
# Cytarabine
# Cytosine-1-beta-D-arabinofuranoside hydrochloride
# D-Cycloserine
# D-ribofuranosylbenzimidazole
# Dantrolene sodium
# Dequalinium chloride hydrate
# Dihydroartemisinin
# Dihydroergotamine
# Dihydroergotamine methanesulfonate
# Dihydroouabain
# Diphenyleneiodonium chloride
# Docetaxel
# Domperidone
# Doxorubicin
# Doxycycline hydrochloride
# Ebastine
# Efavirenz
# Ellipticine
# Emetine dihydrochloride hydrate
# Endoxifen
# Ethinyl Estradiol
# Etoposide
# Flunarizine dihydrochloride
# Fluoxetine hydrochloride
# Fluspirilene
# Forskolin
# Furamidine dihydrochloride
# GANT61
# GBR-12909 dihydrochloride
# GSK-650394
# GSK1210151A
# GW2974
# GW9662
# Gefitinib
# Gemcitabine hydrochloride
# Hydroxychloroquine
# IKK-16 dihydrochloride
# IMS2186
# IN-1130
# Idarubicin
# Idazoxan hydrochloride
# Imatinib
# Imatinib mesylate
# Imipramine hydrochloride
# Iodoacetamide
# Irinotecan
# Isoproterenol
# JFD00244
# JS-K
# K114
# KB-R7493
# KT203
# KU-55933
# KY-05009
# Kenpaullone
# Ketoconazole
# L-741,626
# L-Tryptophan
# LDN-214117
# LP 12 hydrochloride hydrate
# LP44
# LY-294,002 hydrochloride
# Lercanidipine hydrochloride hemihydrate
# Loperamide
# Loperamide hydrochloride
# Lorcainide hydrochloride
# Lubeluzole dihydrochloride
# M-110
# MG 624
# MK-677
# ML-7
# ML240
# ML324
# Maprotiline
# Maprotiline hydrochloride
# Methiothepin mesylate
# Methoxamine hydrochloride
# Metrazoline oxalate
# Mibefradil dihydrochloride
# Mifepristone
# Mycophenolic Acid
# N-p-Tosyl-L-phenylalanine chloromethyl ketone
# NG-Monomethyl-L-arginine acetate
# Nestorone
# Nicardipine hydrochloride
# Niclosamide
# Nisoldipine
# Nocodazole
# Nortriptyline hydrochloride
# Olanzapine
# Ouabain
# PAPP
# PD-407824
# PD153035 hydrochloride
# PF-429242 dihydrochloride
# PMEG hydrate
# Palonosetron hydrochloride
# Paroxetine hydrochloride hemihydrate (MW = 374.83)
# Pazopanib
# Pentamidine
# Pergolide methanesulfonate
# Perphenazine
# Pheniramine maleate
# Phorbol 12-myristate 13-acetate
# Pifithrin-mu
# Pimozide
# Piperlongumine
# Podophyllotoxin
# Prazosin hydrochloride
# Progesterone
# Proguanil
# Promazine hydrochloride
# Propafenone hydrochloride
# Propionylpromazine hydrochloride
# Protriptyline hydrochloride
# Psoralidin
# Quinidine sulfate
# RU-SKI 43 maleate
# Rabeprazole sodium
# Raloxifene hydrochloride
# Ranolazine dihydrochloride
# Reserpine
# Ro 11-1464
# Ro 90-7501
# Roscovitine
# Rotenone
# Ruthenium red
# SB 202190
# SB 415286
# SB743921 hydrochloride
# SID 3712249
# SKF 83959 hydrobromide
# SMER28
# SP600125
# SR 59230A oxalate
# SR9243
# SU1498
# Sertaconazole nitrate
# Supercinnamaldehyde
# Suprafenacine
# T0070907
# TBBz
# TIC10 angular
# Tacrine
# Testosterone
# Thiabendazole
# Thiocolchicine
# Tirapazamine
# Tizanidine hydrochloride
# Topotecan hydrochloride hydrate
# Torin2
# Trifluperidol hydrochloride
# Triflupromazine hydrochloride
# Trilostane
# Trimipramine maleate
# Tyrphostin AG 879
# U-62066
# U0126
# UNC0379 trifluoroacetate salt
# Vincristine sulfate
# WIN 62,577
# WZ4003
# Wiskostatin
# XL388
# Y-27632 dihydrochloride
# Yoda1
# alpha-Lobeline hydrochloride

# %%
println.(plateRMPV[plateRMPV.RMPV .< 0.05,:Condition]);
# Out:
# (+)-Butaclamol hydrochloride
# (+)-Cyclazocine
# (+/-)-Sulfinpyrazone
# (-)-JQ1
# (-)-Perillic acid
# (-)-trans-(1S,2S)-U-50488 hydrochloride
# (S)-(+)-Camptothecin
# (S)-Propranolol hydrochloride
# (±)-Isoproterenol hydrochloride
# (±)-Methoxyverapamil hydrochloride
# (±)-Octoclothepin maleate
# (±)-SKF-38393 hydrochloride
# (±)-Verapamil hydrochloride
# (±)-alpha-Lipoic Acid
# 1,10-Phenanthroline monohydrate
# 2,2'-Bipyridyl
# 2-Phenylaminoadenosine
# 4-(2-Aminoethyl)benzenesulfonyl fluoride hydrochloride
# 5-(N,N-hexamethylene)amiloride
# 5-(N-Ethyl-N-isopropyl)amiloride
# 5-Bromo-2'-deoxyuridine
# 5-Fluorouracil
# 5-azacytidine
# 5alpha-Pregnan-3alpha-ol-20-one
# 6-Nitroso-1,2-benzopyrone
# 7-Cyclopentyl-5-(4-phenoxy)phenyl-7H-pyrrolo[2,3-d]pyrimidin-4-ylamine
# AC-93253 iodide
# AEG 3482
# AMG 9810
# Acepromazine maleate
# Albendazole
# Ammonium pyrrolidinedithiocarbamate
# Amodiaquine
# Ancitabine hydrochloride
# Apomorphine hydrochloride hemihydrate
# BAY 61-3606 hydrochloride hydrate
# BIO
# BMS-193885
# BRD3308
# BTO-1
# BW 723C86
# Benidipine hydrochloride
# Benoxathian hydrochloride
# Benzamil hydrochloride
# Benztropine mesylate
# Brefeldin A from Penicillium brefeldianum
# Brequinar sodium salt hydrate
# Budesonide
# CCCI-01
# CCT137690
# CID 11210285 hydrochloride
# CID2858522
# CP466722
# CYM50358
# Caffeic Acid
# Caffeic acid phenethyl ester
# Cantharidic Acid
# Cantharidin
# Carmofur
# Carvedilol
# Chloroquine
# Chlorprothixene hydrochloride
# Cilengitide trifluoroacetic acid salt
# Cilnidipine
# Clemizole hydrochloride
# Clofarabine
# Clomipramine hydrochloride
# Clotrimazole
# Cyclosporin A
# Cyproterone acetate
# Cytarabine
# Cytosine-1-beta-D-arabinofuranoside hydrochloride
# D-ribofuranosylbenzimidazole
# Dantrolene sodium
# Dequalinium chloride hydrate
# Dihydroartemisinin
# Dihydroergotamine
# Dihydroergotamine methanesulfonate
# Dihydroouabain
# Diphenyleneiodonium chloride
# Docetaxel
# Domperidone
# Doxorubicin
# Doxycycline hydrochloride
# Ebastine
# Efavirenz
# Ellipticine
# Emetine dihydrochloride hydrate
# Endoxifen
# Ethinyl Estradiol
# Etoposide
# Flunarizine dihydrochloride
# Fluoxetine hydrochloride
# Fluspirilene
# Forskolin
# Furamidine dihydrochloride
# GANT61
# GBR-12909 dihydrochloride
# GSK-650394
# GSK1210151A
# GW2974
# GW9662
# Gefitinib
# Gemcitabine hydrochloride
# Hydroxychloroquine
# IKK-16 dihydrochloride
# IMS2186
# IN-1130
# Idarubicin
# Idazoxan hydrochloride
# Imatinib
# Imatinib mesylate
# Imipramine hydrochloride
# Iodoacetamide
# Irinotecan
# JFD00244
# JS-K
# K114
# KB-R7493
# KT203
# KU-55933
# KY-05009
# Kenpaullone
# Ketoconazole
# L-741,626
# L-Tryptophan
# LDN-214117
# LP 12 hydrochloride hydrate
# LP44
# LY-294,002 hydrochloride
# Lercanidipine hydrochloride hemihydrate
# Loperamide
# Loperamide hydrochloride
# Lorcainide hydrochloride
# Lubeluzole dihydrochloride
# M-110
# MG 624
# MK-677
# ML-7
# ML240
# ML324
# Maprotiline
# Maprotiline hydrochloride
# Methiothepin mesylate
# Metrazoline oxalate
# Mibefradil dihydrochloride
# Mifepristone
# Mycophenolic Acid
# N-p-Tosyl-L-phenylalanine chloromethyl ketone
# NG-Monomethyl-L-arginine acetate
# Niclosamide
# Nisoldipine
# Nocodazole
# Nortriptyline hydrochloride
# Ouabain
# PAPP
# PD-407824
# PD153035 hydrochloride
# PF-429242 dihydrochloride
# PMEG hydrate
# Palonosetron hydrochloride
# Paroxetine hydrochloride hemihydrate (MW = 374.83)
# Pazopanib
# Pentamidine
# Perphenazine
# Pheniramine maleate
# Phorbol 12-myristate 13-acetate
# Pifithrin-mu
# Pimozide
# Piperlongumine
# Podophyllotoxin
# Prazosin hydrochloride
# Progesterone
# Proguanil
# Promazine hydrochloride
# Propafenone hydrochloride
# Propionylpromazine hydrochloride
# Protriptyline hydrochloride
# Psoralidin
# Quinidine sulfate
# RU-SKI 43 maleate
# Rabeprazole sodium
# Raloxifene hydrochloride
# Ranolazine dihydrochloride
# Reserpine
# Ro 11-1464
# Ro 90-7501
# Roscovitine
# Rotenone
# Ruthenium red
# SB 202190
# SB 415286
# SB743921 hydrochloride
# SID 3712249
# SKF 83959 hydrobromide
# SMER28
# SP600125
# SR 59230A oxalate
# SR9243
# SU1498
# Sertaconazole nitrate
# Supercinnamaldehyde
# Suprafenacine
# T0070907
# TBBz
# TIC10 angular
# Tacrine
# Thiabendazole
# Thiocolchicine
# Tirapazamine
# Tizanidine hydrochloride
# Topotecan hydrochloride hydrate
# Torin2
# Trifluperidol hydrochloride
# Triflupromazine hydrochloride
# Trilostane
# Trimipramine maleate
# Tyrphostin AG 879
# U-62066
# U0126
# UNC0379 trifluoroacetate salt
# Vincristine sulfate
# WIN 62,577
# WZ4003
# Wiskostatin
# XL388
# Y-27632 dihydrochloride
# Yoda1
# alpha-Lobeline hydrochloride

# %% [markdown]
# ## Display tops and flops

# %%
plateRMPV.Condition[sortperm(plateRMPV.Distance)[1:10]]
# Out:
# 10-element Array{String,1}:
#  "DMSO"
#  "None"
#  "DCEBIO"
#  "Dipyridamole"
#  "Azatadine"
#  "Colchicine"
#  "Chlorpromazine hydrochloride"
#  "Doxazosin mesylate"
#  "Amsacrine hydrochloride"
#  "CGS-15943"

# %%
plateRMPV.Condition[sortperm(plateRMPV.Distance)[(end-9):end]]
# Out:
# 10-element Array{String,1}:
#  "Tyrphostin AG 879"
#  "Triflupromazine hydrochloride"
#  "6-Nitroso-1,2-benzopyrone"
#  "Nortriptyline hydrochloride"
#  "Mibefradil dihydrochloride"
#  "Endoxifen"
#  "GBR-12909 dihydrochloride"
#  "Loperamide hydrochloride"
#  "BMS-193885"
#  "RU-SKI 43 maleate"

# %%
Random.seed!(3895)
umTPM = umap(expTransformed, metric = CosineDist(), min_dist = 2)
umTPM = convert(DataFrame, umTPM')
rename!(umTPM, [:UMAP1, :UMAP2]);
umTPM.Compound = aggregatedData.CompoundName;

# %%
subsetCompounds = ["Tyrphostin AG 879", "Loperamide", "DMSO", "Endoxifen"]
subsetEntries = Bool.(map(sum, eachcol(map(x -> occursin.(x, umTPM.Compound), subsetCompounds)))[1])
ggplot(umTPM[subsetEntries,:], aes(:UMAP1, :UMAP2)) + 
    geom_point(aes(color = :Compound), alpha = 0.8) +
    coord_fixed() + 
    theme(var"legend.position"="bottom", var"legend.spacing.x" = unit(0.35, "cm"), 
    var"legend.spacing.y" = unit(0, "cm")) + 
    guides(color=guide_legend(nrow=3,byrow=true))
# Out:
# RObject{VecSxp}

# %%
subsetCompounds = ["Azatadine", "Colchicine", "CGS-15943", "DMSO", "Dipyridamole"]
subsetEntries = Bool.(map(sum, eachcol(map(x -> occursin.(x, umTPM.Compound), subsetCompounds)))[1])
ggplot(umTPM[subsetEntries,:], aes(:UMAP1, :UMAP2)) + 
    geom_point(aes(color = :Compound), alpha = 0.8) +
    coord_fixed() + 
    theme(var"legend.position"="bottom", var"legend.spacing.x" = unit(0.35, "cm"), 
    var"legend.spacing.y" = unit(0, "cm")) + 
    guides(color=guide_legend(nrow=3,byrow=true))
# Out:
# RObject{VecSxp}

# %% [markdown]
# ## Compare to other plate
# Note that "DMSO" and "None" (control wells) are not hits. To judge the reproducibility of the experiments, we now want to compare the hit compounds found in both plates compared to the total numbers of compound tested (311) with an independence test.

# %%
sparseRMPV = CSV.read("data/RMPV.csv", DataFrame);

# %%
hit1500 = plateRMPV.Condition[plateRMPV.RMPV .< 0.1]
hit750 = sparseRMPV.Condition[sparseRMPV.RMPV .< 0.1];

# %%
# Jaccard coeff
length(hit750 ∩ hit1500) / length(hit750 ∪ hit1500)
# Out:
# 0.7781818181818182

# %%
# Total number of compounds
N = 311
# Contingency table 
# Rows = hits at 1500c/w or not
# Columns = hits at 750c/w or not
O = zeros(Int,2,2)
O[1,1] = length(hit750 ∩ hit1500)
O[2,1] = length(hit750) - O[1,1]
O[1,2] = length(hit1500) - O[1,1]
O[2,2] = N - sum(O)
O
# Out:
# 2×2 Array{Int64,2}:
#  214  26
#   35  36

# %%
# Expectation if plates are independent
E = sum.(eachrow(O))./N * (sum.(eachcol(O))./N)'
# Out:
# 2×2 Array{Float64,2}:
#  0.61786   0.153845
#  0.182783  0.0455123

# %%
chisq = N*sum((O/N - E).^2 ./E)
# Out:
# 54.56960963648627

# %%
using Distributions 
# (number of rows - 1)*(number of columns - 1)
ccdf(Chisq(1), chisq)
# Out:
# 1.5003800454572425e-13

# %% [markdown]
# ## Visualize distances in both plates

# %%
bothRMPV = innerjoin(sparseRMPV, plateRMPV,
          makeunique=true,
          on = :Condition)
# Out:
# 276×6 DataFrame
#  Row │ RMPV         Distance  Condition                          RMPV_1        ⋯
#      │ Float64      Float64   String                             Float64       ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 0.247918     0.462109  (+)-Butaclamol hydrochloride       0.0           ⋯
#    2 │ 0.0288018    0.628212  (+)-Cyclazocine                    0.00124783
#    3 │ 0.00191724   0.74496   (+/-)-Sulfinpyrazone               0.015413
#    4 │ 0.000368212  0.769655  (-)-JQ1                            0.0
#    5 │ 0.157001     0.518261  (-)-Perillic acid                  0.00182222    ⋯
#    6 │ 0.00161628   0.726586  (-)-Quinpirole hydrochloride       0.106131
#    7 │ 0.00870505   0.678042  (-)-trans-(1S,2S)-U-50488 hydroc…  0.027791
#    8 │ 0.0286805    0.623367  (S)-Propranolol hydrochloride      0.0
#    9 │ 0.0          0.945019  (±)-Isoproterenol hydrochloride    0.0           ⋯
#   10 │ 0.000703797  0.742031  (±)-Methoxyverapamil hydrochlori…  0.000652273
#   11 │ 0.0782519    0.556447  (±)-Metoprolol (+)-tartrate        0.143613
#   ⋮  │      ⋮          ⋮                      ⋮                       ⋮        ⋱
#  267 │ 0.00133174   0.721797  UNC0379 trifluoroacetate salt      0.0
#  268 │ 0.0          0.903559  Vinblastine                        0.18595       ⋯
#  269 │ 0.000368212  0.744022  Vincristine sulfate                0.0
#  270 │ 0.0100583    0.68547   WIN 62,577                         0.00208187
#  271 │ 0.0          0.997446  WZ4003                             0.0
#  272 │ 0.0          0.900039  Wiskostatin                        0.0           ⋯
#  273 │ 0.0          0.987989  XL388                              0.0
#  274 │ 0.0267891    0.641298  Y-27632 dihydrochloride            0.00568317
#  275 │ 0.0          0.867396  Yoda1                              0.0443088
#  276 │ 0.0106818    0.658513  alpha-Lobeline hydrochloride       0.0347489     ⋯
#                                                   2 columns and 255 rows omitted

# %%
cpd_to_label = ["DMSO", "Vinblastine", "Wiskostatin"]
bothRMPV.Label = [x in cpd_to_label ? x : "" for x in bothRMPV.Condition];

# %%
gp = ggplot(bothRMPV, aes(x = :RMPV, y = :RMPV_1)) +
    geom_point(alpha = 0.2) +
    geom_density_2d() +
    geom_vline(xintercept = 0.1, lty = 2) + 
    geom_hline(yintercept = 0.1, lty = 2) + 
    geom_label_repel(aes(label = :Label), size = 5) + 
    xlab("Plate at 750 cells/well") +
    ylab("Plate at 1500 cells/well") +
    ggtitle("FDR-corrected p-value per treatment") +
    RObject(nothing)
gp
# Out:
# RObject{VecSxp}
# ┌ Warning: RCall.jl: Warning: ggrepel: 2 unlabeled data points (too many overlaps). Consider increasing max.overlaps
# └ @ RCall /opt/julia/packages/RCall/3mHXJ/src/io.jl:160

# %%
ggsave("fig/RMPV_agreement.pdf", gp);
# Out:
# REvalError: Saving 7 x 7 in image
# Warning in grid.Call(C_stringMetric, as.graphicsAnnot(x$label)) :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_stringMetric, as.graphicsAnnot(x$label)) :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_stringMetric, as.graphicsAnnot(x$label)) :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_stringMetric, as.graphicsAnnot(x$label)) :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_stringMetric, as.graphicsAnnot(x$label)) :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_stringMetric, as.graphicsAnnot(x$label)) :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_stringMetric, as.graphicsAnnot(x$label)) :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_stringMetric, as.graphicsAnnot(x$label)) :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_stringMetric, as.graphicsAnnot(x$label)) :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_stringMetric, as.graphicsAnnot(x$label)) :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_stringMetric, as.graphicsAnnot(x$label)) :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_stringMetric, as.graphicsAnnot(x$label)) :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_stringMetric, as.graphicsAnnot(x$label)) :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_stringMetric, as.graphicsAnnot(x$label)) :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning: ggrepel: 1 unlabeled data points (too many overlaps). Consider increasing max.overlaps
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Warning in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y,  :
#   font family 'Arial' not found in PostScript font database
# Error in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y,  :
#   invalid font type
# Calls: <Anonymous> ... drawDetails -> drawDetails.text -> grid.Call.graphics
#
# Stacktrace:
#  [1] handle_eval_stderr(; as_warning::Bool) at /opt/julia/packages/RCall/3mHXJ/src/io.jl:162
#  [2] reval_p(::Ptr{LangSxp}, ::Ptr{EnvSxp}) at /opt/julia/packages/RCall/3mHXJ/src/eval.jl:99
#  [3] reval_p at /opt/julia/packages/RCall/3mHXJ/src/eval.jl:95 [inlined]
#  [4] rcall_p(::RObject{ClosSxp}, ::String, ::Vararg{Any,N} where N; kwargs::Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}) at /opt/julia/packages/RCall/3mHXJ/src/language.jl:30
#  [5] rcall_p(::RObject{ClosSxp}, ::String, ::Vararg{Any,N} where N) at /opt/julia/packages/RCall/3mHXJ/src/language.jl:30
#  [6] rcall(::RObject{ClosSxp}, ::String, ::Vararg{Any,N} where N; kwargs::Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}) at /opt/julia/packages/RCall/3mHXJ/src/language.jl:37
#  [7] rcall(::RObject{ClosSxp}, ::String, ::Vararg{Any,N} where N) at /opt/julia/packages/RCall/3mHXJ/src/language.jl:37
#  [8] (::RObject{ClosSxp})(::String, ::Vararg{Any,N} where N; kwargs::Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}) at /opt/julia/packages/RCall/3mHXJ/src/language.jl:39
#  [9] (::RObject{ClosSxp})(::String, ::Vararg{Any,N} where N) at /opt/julia/packages/RCall/3mHXJ/src/language.jl:39
#  [10] top-level scope at In[45]:1
#  [11] include_string(::Function, ::Module, ::String, ::String) at ./loading.jl:1091
